# %%
#%matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(-1,1, 100)

# %%
plt.plot(x, np.sqrt(1-x**2))
plt.plot(x, -np.sqrt(1-x**2))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
t = np.linspace(0, 2* np.pi, 100)

# %%
x = np.cos(t)
y = np.sin(t)
plt.plot(x,y)

# %%
plt.figure(figsize=(5,5))
t = np.linspace(0, 2* np.pi, 6)
plt.plot(np.cos(t), np.sin(t))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(5,5))
t = np.linspace(0, 4* np.pi, 6)
plt.plot(np.cos(t), np.sin(t))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(5,5))
t = np.linspace(0, 2* np.pi, 11)
r = np.array([2,1]*5+[2])
plt.plot(r*np.cos(t), r*np.sin(t))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure(figsize=(5,5))
t = np.linspace(0, 2* np.pi, 11)
r = np.arange(11)%2+1
plt.plot(r*np.cos(t-0.3), r*np.sin(t-0.3))

t = np.linspace(0, 2* np.pi, 101)
r = 2
plt.plot(r*np.cos(t), r*np.sin(t))


t = np.linspace(0, 2* np.pi, 5)
r = 2
plt.plot(r*np.cos(t), r*np.sin(t))
plt.savefig('magic circle.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from PIL import Image
Image.open('magic circle.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500>
